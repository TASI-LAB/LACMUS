# %% [markdown]
# ## Quick Demo for Mnsit Dataset
# Here is the quick demo of Mnist dataset.

# %% [markdown]
# Step1: Train the vqvae model or using the pre-trained model

# %% [markdown]
# ! python3 VQ-VAE.py --output-folder [NAME_OF_OUTPUT_FOLDER] --data-folder [PATH_TO_MNIST_dataset] --device ['cpu' or 'cuda' ] --hidden-size [SIZE] --k [NUMBER] --batch-size [BATCH_SIZE] --num_epoch [NUMBER_OF_EPOCHS] --lr [LEARNING_RATE] --beta [VALUE] --num-workers [NUMBER_OF_WORKERS]

# %% [markdown]
# Step2: Train the classfier model

# %%
! python classifier.py
# Out:
# Epoch: 001/010 | Train: 88.962%
# Epoch: 002/010 | Train: 94.587%
# Epoch: 003/010 | Train: 96.195%
# Epoch: 004/010 | Train: 96.897%
# Epoch: 005/010 | Train: 97.435%
# Epoch: 006/010 | Train: 97.172%
# Epoch: 007/010 | Train: 97.973%
# Epoch: 008/010 | Train: 98.058%
# Epoch: 009/010 | Train: 98.310%
# Epoch: 010/010 | Train: 98.253%
# Test accuracy: 97.87%

# %% [markdown]
# Step3: Generate Augmentation Samples

# %%
# Generate samples with concept 367
! python main.py --mode gs_c --model weights/best.pt --classfier-model mnist.pth --concept 367
# Out:
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# model acc: 0.9834166765213013
# Finished concept 367

# %%
# Generate samples with all concept
! python main.py --mode gs --model weights/best.pt --classfier-model mnist.pth
# Out:
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# model acc: 0.9836666584014893
# Finished concept 0
# Finished concept 1
# Finished concept 2
# Finished concept 3
# Finished concept 4
# Finished concept 5
# Finished concept 6
# Finished concept 7
# Finished concept 8
# Finished concept 9
# Finished concept 10
# Finished concept 11
# Finished concept 12
# Finished concept 13
# Finished concept 14
# Finished concept 15
# Finished concept 16
# Finished concept 17
# Finished concept 18
# Finished concept 19
# Finished concept 20
# Finished concept 21
# Finished concept 22
# Finished concept 23
# Finished concept 24
# Finished concept 25
# ...

# %%
# Merge samples for all concept
! python merge_aug_sample.py
# Out:
# (310, 28, 28)
# (311, 28, 28)
# (265, 28, 28)
# (346, 28, 28)
# (280, 28, 28)
# (382, 28, 28)
# (309, 28, 28)
# (368, 28, 28)
# (338, 28, 28)
# (279, 28, 28)
# (329, 28, 28)
# (235, 28, 28)
# (354, 28, 28)
# (287, 28, 28)
# (300, 28, 28)
# (253, 28, 28)
# (347, 28, 28)
# (326, 28, 28)
# (306, 28, 28)
# (272, 28, 28)
# (253, 28, 28)
# (234, 28, 28)
# (280, 28, 28)
# (296, 28, 28)
# (221, 28, 28)
# (286, 28, 28)
# (340, 28, 28)
# (321, 28, 28)
# (355, 28, 28)
# (271, 28, 28)
# (753, 28, 28)
# (284, 28, 28)
# (330, 28, 28)
# (300, 28, 28)
# (319, 28, 28)
# (305, 28, 28)
# (250, 28, 28)
# (280, 28, 28)
# (306, 28, 28)
# (526, 28, 28)
# (316, 28, 28)
# (226, 28, 28)
# (292, 28, 28)
# (273, 28, 28)
# (380, 28, 28)
# (592, 28, 28)
# (263, 28, 28)
# (282, 28, 28)
# (311, 28, 28)
# (370, 28, 28)
# (285, 28, 28)
# (301, 28, 28)
# (284, 28, 28)
# (479, 28, 28)
# (342, 28, 28)
# (336, 28, 28)
# (284, 28, 28)
# (233, 28, 28)
# (345, 28, 28)
# (264, 28, 28)
# (292, 28, 28)
# (355, 28, 28)
# ...

# %% [markdown]
# step4: Finetuning model

# %%
# You need to add the test attack sample path in testing_Adv_path.py

# Fintune with concept 367
! python main.py --mode ft_c --model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/weights/best.pt --classfier-model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/mnist.pth --concept 367
# Out:
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# model_preformance: 0.9786999821662903
# -----------------------------------------------------------------------
# Start Finetuning
# Epoch: 001/010 | Train: 70.034%
# ...

# %%
# Fintune with all concept
! python main.py --mode ft --model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/weights/best.pt --classfier-model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/mnist.pth
# Out:
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# model_preformance: 0.9786999821662903
# -----------------------------------------------------------------------
# Start Finetuning
# Epoch: 001/010 | Train: 98.014%
# ...

# %%
# Fintune with concept 367 and adv sample for training set fgsm
# !python main.py --mode ft_m_c --model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/weights/best.pt --classfier-model /bowen/d61-ai-security/work/zho086/dnn-gp/LACMUS/mnist.pth --concept 367  --adv-path adv_sample/train_mnist_fgsm_0.03125.npy --adv-label adv_sample/train_mnist_fgsm_0.03125_label.npy
# Out:
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:75: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /home/zho086/anaconda3/envs/ldm/lib/python3.8/site-packages/torchvision/datasets/mnist.py:65: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# model_preformance: 0.9786999821662903
# -----------------------------------------------------------------------
# Start Finetuning
# Epoch: 001/010 | Train: 74.591%
# ...
